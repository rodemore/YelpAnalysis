# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
ngrams_dir = '/content/drive/MyDrive/0AccTeam/N_grams_data/'

# %%
bigrams = pd.read_csv(ngrams_dir + "bigrams.csv")

# %%
bigrams.head(20)
# Out:
#                  Unnamed: 0      0
# 0         ('first', 'time')  58152
# 1            ('go', 'back')  58144
# 2          ('come', 'back')  54211
# 3          ('food', 'good')  51841
# 4        ('really', 'good')  51717
# 5   ('customer', 'service')  50841
# 6         ('great', 'food')  48319
# 7      ('great', 'service')  44020
# 8         ('food', 'great')  43330
# 9   ('highly', 'recommend')  39964
# 10         ('ice', 'cream')  39599
# 11     ('service', 'great')  38627
# 12       ('pretty', 'good')  38558
# 13         ('good', 'food')  38490
# 14        ('love', 'place')  37101
# 15       ('great', 'place')  36604
# 16        ('happy', 'hour')  34485
# 17         ('next', 'time')  33896
# 18       ('coming', 'back')  28842
# 19        ('every', 'time')  28578

# %%
bigrams2 = pd.read_csv(ngrams_dir + "bigrams1.csv")

# %%
bigrams.head(20)
# Out:
#                  Unnamed: 0      0
# 0         ('first', 'time')  58152
# 1            ('go', 'back')  58144
# 2          ('come', 'back')  54211
# 3          ('food', 'good')  51841
# 4        ('really', 'good')  51717
# 5   ('customer', 'service')  50841
# 6         ('great', 'food')  48319
# 7      ('great', 'service')  44020
# 8         ('food', 'great')  43330
# 9   ('highly', 'recommend')  39964
# 10         ('ice', 'cream')  39599
# 11     ('service', 'great')  38627
# 12       ('pretty', 'good')  38558
# 13         ('good', 'food')  38490
# 14        ('love', 'place')  37101
# 15       ('great', 'place')  36604
# 16        ('happy', 'hour')  34485
# 17         ('next', 'time')  33896
# 18       ('coming', 'back')  28842
# 19        ('every', 'time')  28578

# %%
trigrams = pd.read_csv(ngrams_dir + "trigrams.csv")

# %%
trigrams.head(30)
# Out:
#                               Unnamed: 0     0
# 0         ('definitely', 'come', 'back')  8640
# 1           ('food', 'great', 'service')  7237
# 2                 ('wait', 'go', 'back')  6367
# 3             ('great', 'food', 'great')  6167
# 4           ('definitely', 'go', 'back')  6161
# 5       ('definitely', 'coming', 'back')  6124
# 6                ('would', 'go', 'back')  5483
# 7           ('service', 'great', 'food')  5428
# 8       ('great', 'customer', 'service')  5417
# 9              ('would', 'come', 'back')  5081
# 10  ('would', 'definitely', 'recommend')  4999
# 11           ('food', 'good', 'service')  4943
# 12      ('highly', 'recommend', 'place')  4941
# 13                ('mac', 'n', 'cheese')  4750
# 14      ('would', 'highly', 'recommend')  4440
# 15            ('food', 'really', 'good')  4190
# 16               ('come', 'back', 'try')  4089
# 17                 ('go', 'back', 'try')  3896
# 18       ('would', 'definitely', 'come')  3843
# ...

# %%
trigrams2 = pd.read_csv(ngrams_dir + "trigrams1.csv")

# %%
trigrams2.head(20)
# Out:
#                               Unnamed: 0     0
# 0         ('definitely', 'come', 'back')  8672
# 1           ('food', 'great', 'service')  7234
# 2                 ('wait', 'go', 'back')  6365
# 3             ('great', 'food', 'great')  6202
# 4       ('definitely', 'coming', 'back')  6198
# 5           ('definitely', 'go', 'back')  6040
# 6                ('would', 'go', 'back')  5422
# 7           ('service', 'great', 'food')  5374
# 8       ('great', 'customer', 'service')  5360
# 9              ('would', 'come', 'back')  5167
# 10  ('would', 'definitely', 'recommend')  5005
# 11      ('highly', 'recommend', 'place')  4967
# 12           ('food', 'good', 'service')  4855
# 13                ('mac', 'n', 'cheese')  4673
# 14      ('would', 'highly', 'recommend')  4554
# 15            ('food', 'really', 'good')  4227
# 16               ('come', 'back', 'try')  4059
# 17          ('sweet', 'potato', 'fries')  3873
# 18                 ('go', 'back', 'try')  3867
# ...

# %%
fourgrams = pd.read_csv(ngrams_dir + "fograms.csv")

# %%
fourgrams.head(30)
# Out:
#                                         Unnamed: 0     0
# 0          ('would', 'definitely', 'come', 'back')  3059
# 1            ('great', 'food', 'great', 'service')  2659
# 2            ('would', 'definitely', 'go', 'back')  2302
# 3               ('story', 'line', 'make', 'sense')  1515
# 4                  ('got', 'better', 'last', '20')  1513
# 5       ('watch', 'sitting', 'directly', 'middle')  1513
# 6               ('5', 'minutes', 'hand', 'shadow')  1513
# 7            ('live', 'productions', 'maybe', '7')  1513
# 8   ('money', 'disappointed', 'wasted', 'evening')  1513
# 9       ('20', 'minutes', 'amazing', 'especially')  1513
# 10     ('activity', 'included', 'ridiculous', '5')  1513
# 11                ('10', 'minutes', 'like', 'bad')  1513
# 12                    ('maybe', '7', '10', 'year')  1513
# 13               ('2', 'nights', 'vegas', 'first')  1513
# 14            ('bad', 'vaudeville', 'show', 'top')  1513
# ...

# %%
for i in fourgrams.head(100).iterrows():
  print(i[1]["Unnamed: 0"])
# Out:
# ('would', 'definitely', 'come', 'back')
# ('great', 'food', 'great', 'service')
# ('would', 'definitely', 'go', 'back')
# ('story', 'line', 'make', 'sense')
# ('got', 'better', 'last', '20')
# ('watch', 'sitting', 'directly', 'middle')
# ('5', 'minutes', 'hand', 'shadow')
# ('live', 'productions', 'maybe', '7')
# ('money', 'disappointed', 'wasted', 'evening')
# ('20', 'minutes', 'amazing', 'especially')
# ('activity', 'included', 'ridiculous', '5')
# ('10', 'minutes', 'like', 'bad')
# ('maybe', '7', '10', 'year')
# ('2', 'nights', 'vegas', 'first')
# ('bad', 'vaudeville', 'show', 'top')
# ('seats', 'would', 'left', 'kept')
# ('hand', 'shadow', 'puppets', 'back')
# ('know', 'exact', 'time', 'kept')
# ('hour', '10', 'minutes', 'like')
# ('show', 'top', 'pointless', 'activity')
# ('get', 'better', 'story', 'line')
# ('included', 'ridiculous', '5', 'minutes')
# ('sense', 'acrobats', 'last', '20')
# ('acrobats', 'last', '20', 'minutes')
# ('real', 'acrobats', 'know', 'exact')
# ...
